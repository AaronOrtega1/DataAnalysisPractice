# %% [markdown]
# ## <center> Online Retail Exploratory Data Analysis</center>
# ### <center> Univariate </center>
# ---
#
# **Name**: Francisco Aarón Ortega Anguiano

# %% [markdown]
# #### Import important libraries and read the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

retail_df = pd.read_csv('db/Online-Retail-Transformed.csv')

retail_df.head()
# Out:
# /tmp/ipykernel_312971/239850922.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   retail_df = pd.read_csv('db/Online-Retail-Transformed.csv')
#   InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 0    536365  2010-12-01  08:26:00 AM    85123A
# 1    536365  2010-12-01  08:26:00 AM     71053
# 2    536365  2010-12-01  08:26:00 AM    84406B
# 3    536365  2010-12-01  08:26:00 AM    84029G
# 4    536365  2010-12-01  08:26:00 AM    84029E
#
#                            Description  Quantity  UnitPrice  Totalsale  \
# 0   white hanging heart t-light holder         6       2.55      15.30
# 1                  white metal lantern         6       3.39      20.34
# 2       cream cupid hearts coat hanger         8       2.75      22.00
# 3  knitted union flag hot water bottle         6       3.39      20.34
# 4        red woolly hottie white heart         6       3.39      20.34
#
# ...

# %%
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525460 entries, 0 to 525459
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    525460 non-null  object
#  1   InvoiceDate  525460 non-null  object
#  2   InvoiceTime  525460 non-null  object
#  3   StockCode    525460 non-null  object
#  4   Description  525460 non-null  object
#  5   Quantity     525460 non-null  int64
#  6   UnitPrice    525460 non-null  float64
#  7   Totalsale    525460 non-null  float64
#  8   CustomerID   525460 non-null  float64
#  9   Country      525460 non-null  object
#  10  Year         525460 non-null  int64
#  11  Month        525460 non-null  int64
#  12  Season       525460 non-null  object
#  13  AM_or_PM     525460 non-null  object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 56.1+ MB

# %%
retail_df.hist(figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'UnitPrice'}>],
#        [<Axes: title={'center': 'Totalsale'}>,
#         <Axes: title={'center': 'CustomerID'}>],
#        [<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Month'}>]], dtype=object)

# %%
from lib.data_visualizer import DataVisualizer

visualizer = DataVisualizer(retail_df)

visualizer.plot_heatmap("Correlation Heatmap")

# %% [markdown]
# Totalsale and Quantity show a correlation between them.

# %%
visualizer.number_of_unique()
# Out:
# InvoiceNo Column has 20136 number of unique values.
# InvoiceDate Column has 305 number of unique values.
# InvoiceTime Column has 740 number of unique values.
# StockCode Column has 3925 number of unique values.
# Description Column has 4059 number of unique values.
# Quantity Column has 383 number of unique values.
# UnitPrice Column has 1292 number of unique values.
# Totalsale Column has 4597 number of unique values.
# CustomerID Column has 4340 number of unique values.
# Country Column has 38 number of unique values.
# Year Column has 2 number of unique values.
# Month Column has 12 number of unique values.
# Season Column has 4 number of unique values.
# AM_or_PM Column has 2 number of unique values.

# %%
visualizer.barplot_percentage("StockCode", "Top 12 StockCodes")

# %%
visualizer.barplot_percentage("Country", "Top 12 Countries")

# %% [markdown]
# United Kingdom has 91.3% of all the invoices.

# %%
visualizer.barplot_percentage("Description", "Top 5 Items", 5)

# %%
visualizer.barplot_percentage("Year", "Count VS Year")

# %% [markdown]
# Almost all the invoices are from the year 2011.

# %%
visualizer.oldest_latest_date("InvoiceDate")
# Out:
# The oldest date is: 2010-12-01, while the latest date is: 2011-12-09

# %%
visualizer.barplot_percentage("Month", "Months")

# %% [markdown]
# Most of the invoices are from the last 3 months of the year, taking the **more than 30%** of all the invoices.

# %%
visualizer.barplot_percentage("Season", "Season by Proportion")

# %% [markdown]
# The season Fall has the most invoices, 2 of the top 3 months with more invoices are from this season.

# %%
visualizer.barplot_percentage("AM_or_PM", "After Midday vs. Before Midday")

# %% [markdown]
# More than **70%** of all the invoice are made in the post midday.
